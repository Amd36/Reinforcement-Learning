# %% [markdown]
# # Deep Q-Network Implementation
# Here I have tried to include the Double DQN with experience replay in batches. The loss update equation is as follows:
#
# $$
# Q(s_t, a_t; \theta) \leftarrow Q(s_t, a_t; \theta) + \alpha [r_t + \gamma \max_{a} Q(s_{t+1}, a; \theta^-) - Q(s_t, a_t; \theta)]
# $$
#    Where:
#    - $\theta$ represents the parameters of the main network
#    - $\theta^-$ represents the parameters of the target network
#
# Here we have `self.model` and `self.target_model` as the $\theta$ and $\theta^-$

# %%
import numpy as np
import random
from collections import deque
import gymnasium as gym
import tensorflow as tf
from tensorflow.keras import Model, layers
import os

# %%
env = gym.make("CartPole-v1")
env.reset(seed=42)

state_size = env.observation_space.shape[0]
action_size = env.action_space.n

print("State size:", state_size)
print("Action size:", action_size)
# Out:
# State size: 4
# Action size: 2

# %%
class DQN(Model):
    def __init__(self, state_size, action_size, **kwargs):
        super(DQN, self).__init__(**kwargs)
        self.state_size = state_size
        self.action_size = action_size
        self.dense1 = layers.Dense(24, activation='relu', input_shape=(state_size,))
        self.dense2 = layers.Dense(24, activation='relu')
        self.out = layers.Dense(action_size, activation='linear')

    def call(self, x):
        x = self.dense1(x)
        x = self.dense2(x)
        return self.out(x)

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'state_size': self.state_size,
            'action_size': self.action_size
        })
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)

# %%
memory = deque(maxlen=2000)

# %% [markdown]
# ## The Agent
# The agent tries to balance a pole on a moving cart. I have used the OpenAI Gymnasium for this environment.
#
# Within this environment, we have two actions for the cart:
# 1. Moving Left (0)
# 2. Moving Right (1)
#
# With the state observations:
# 1. **Cart Position**: -4.8 to 4.8
# 2. **Cart Velocity**: -inf to inf
# 3. **Pole Angle**: -24° to 24°
# 4. **Pole Angular Velocity**: -inf to inf
#
# And termination conditions:
# 1. **Termination**: Pole Angle > ±12°
# 2. **Termination**: Cart Position > ±2.4
# 3. **Truncation**: Episode length > 500

# %%
class DQNAgent:
    def __init__(self, state_size, action_size, gamma=0.99, epsilon=1.0, epsilon_min=0.01, epsilon_decay=0.995, learning_rate=0.001, batch_size=64):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = gamma  
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.memory = deque(maxlen=2000)
        
        self.model = self._build_model()
        self.target_model = self._build_model()
        self.update_target_model()

        self.optimizer = tf.keras.optimizers.Adam(learning_rate=self.learning_rate)

    def _build_model(self):
        model = DQN(self.state_size, self.action_size)
        return model

    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
    
    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        q_values = self.model.predict(state, verbose=0)
        return np.argmax(q_values[0])

    def replay(self):
        if len(self.memory) < self.batch_size:
            return
        minibatch = random.sample(self.memory, self.batch_size)
        
        for state, action, reward, next_state, done in minibatch:
            with tf.GradientTape() as tape:
                q_values = self.model(np.array([state]), training=True)
                q_value = q_values[0][action]

                if done:
                    target = reward
                else:
                    next_action = np.argmax(self.model(np.array([next_state]))[0].numpy())
                    t = self.target_model(np.array([next_state]))[0][next_action]
                    target = reward + self.gamma * t

                loss = tf.reduce_mean(tf.square(target - q_value))

            grads = tape.gradient(loss, self.model.trainable_variables)
            self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))

    def save_model(self, filepath):
        self.model.save(filepath)

    def load_model(self, filepath):
        self.model = tf.keras.models.load_model(filepath, custom_objects={'DQN': DQN})
        self.target_model = tf.keras.models.load_model(filepath, custom_objects={'DQN': DQN})

# %%
batch_size = 64
n_episodes = 500
gamma = 0.95
epsilon = 1.0
epsilon_min = 0.01
epsilon_decay = 0.995
learning_rate = 0.001
target_update_freq = 10

# %%
output_dir = "./saved_models/"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

agent = DQNAgent(state_size, action_size, gamma, epsilon, epsilon_min, epsilon_decay, learning_rate, batch_size)
done = False

for e in range(n_episodes):
    state = env.reset()[0]
    state = np.reshape(state, [1, state_size])
    total_reward = 0

    for time in range(500):
        action = agent.act(state)
        next_state, reward, done, truncated, _ = env.step(action)

        done = done or truncated
        next_state = np.reshape(next_state, [1, state_size])
        agent.remember(state[0], action, reward, next_state[0], done)
        state = next_state
        total_reward += reward

        if done:
            print(f"Episode: {e+1}/{n_episodes}, Score: {time}, Epsilon: {agent.epsilon:.2}")
            break
            
    if len(agent.memory) > batch_size:
        agent.replay()

    if agent.epsilon > agent.epsilon_min:
        agent.epsilon *= agent.epsilon_decay

    if e % target_update_freq == 0:
        agent.update_target_model()

    if (e + 1) % 50 == 0:
        agent.model.save_weights(os.path.join(output_dir, f"weights_{e+1:04d}.weights.h5"))

agent.save_model(os.path.join(output_dir, "dqn_model.keras"))
# Out:
# Episode: 1/500, Score: 28, Epsilon: 1.0
# Episode: 2/500, Score: 33, Epsilon: 0.99
# Episode: 3/500, Score: 14, Epsilon: 0.99
# Episode: 4/500, Score: 14, Epsilon: 0.99
# Episode: 5/500, Score: 27, Epsilon: 0.98
# Episode: 6/500, Score: 12, Epsilon: 0.98
# Episode: 7/500, Score: 19, Epsilon: 0.97
# Episode: 8/500, Score: 13, Epsilon: 0.97
# Episode: 9/500, Score: 23, Epsilon: 0.96
# Episode: 10/500, Score: 11, Epsilon: 0.96
# Episode: 11/500, Score: 8, Epsilon: 0.95
# Episode: 12/500, Score: 24, Epsilon: 0.95
# Episode: 13/500, Score: 10, Epsilon: 0.94
# Episode: 14/500, Score: 20, Epsilon: 0.94
# Episode: 15/500, Score: 9, Epsilon: 0.93
# Episode: 16/500, Score: 11, Epsilon: 0.93
# Episode: 17/500, Score: 12, Epsilon: 0.92
# Episode: 18/500, Score: 24, Epsilon: 0.92
# Episode: 19/500, Score: 13, Epsilon: 0.91
# Episode: 20/500, Score: 70, Epsilon: 0.91
# Episode: 21/500, Score: 19, Epsilon: 0.9
# Episode: 477/500, Score: 124, Epsilon: 0.092
# Episode: 478/500, Score: 15, Epsilon: 0.092
# Episode: 479/500, Score: 119, Epsilon: 0.091
# Episode: 480/500, Score: 16, Epsilon: 0.091
# Episode: 481/500, Score: 123, Epsilon: 0.09
# Episode: 482/500, Score: 121, Epsilon: 0.09
# Episode: 483/500, Score: 120, Epsilon: 0.089
# Episode: 484/500, Score: 13, Epsilon: 0.089
# Episode: 485/500, Score: 144, Epsilon: 0.088
# Episode: 486/500, Score: 17, Epsilon: 0.088
# Episode: 487/500, Score: 142, Epsilon: 0.088
# Episode: 488/500, Score: 106, Epsilon: 0.087
# Episode: 489/500, Score: 12, Epsilon: 0.087
# Episode: 490/500, Score: 117, Epsilon: 0.086
# Episode: 491/500, Score: 119, Epsilon: 0.086
# Episode: 492/500, Score: 138, Epsilon: 0.085
# Episode: 493/500, Score: 128, Epsilon: 0.085
# Episode: 494/500, Score: 123, Epsilon: 0.084
# Episode: 495/500, Score: 10, Epsilon: 0.084
# Episode: 496/500, Score: 131, Epsilon: 0.084
# Episode: 497/500, Score: 143, Epsilon: 0.083
# Episode: 498/500, Score: 129, Epsilon: 0.083
# Episode: 499/500, Score: 124, Epsilon: 0.082
# Episode: 500/500, Score: 119, Epsilon: 0.082

# %%
def render_episode(agent, model_path, num_episodes=1):
    # Load the model
    agent.load_model(model_path)
    
    env = gym.make('CartPole-v1', render_mode='human')
    for episode in range(num_episodes):
        state, _ = env.reset()
        state = state.reshape(1, -1)
        done = False
        total_reward = 0
        while not done:
            env.render()
            action = agent.act(state)
            next_state, reward, done, truncated, _ = env.step(action)
            next_state = next_state.reshape(1, -1)
            total_reward += reward
            state = next_state
            if truncated:
                done = True
        print(f"Episode {episode + 1} reward: {total_reward}")
    env.close()

# Initializing saved model
state_size = 4
action_size = 2
agent = DQNAgent(state_size, action_size)
agent.epsilon = 0.0  # 0.0 for pure exploitation

# Load the model and render episodes
model_path = "./saved_models/dqn_model.keras"
render_episode(agent, model_path, num_episodes=3)
# Out:
# c:\Users\Junayed\anaconda3\envs\rl_env_new\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:From c:\Users\Junayed\anaconda3\envs\rl_env_new\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Episode 1 reward: 134.0
# Episode 2 reward: 131.0
# Episode 3 reward: 131.0

# %% [markdown]
# Here we can observe that the rewards are not as we had hoped because the model is simple and has little regularizations and no dropout layers in between.
#
# So I have tried the DQN from `stable_baseline3` to get the same model and it returns a better trained agent.

# %%
import os
from stable_baselines3 import DQN
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.vec_env import DummyVecEnv

LOG_DIR = "DQN_logs"
MODEL_DIR = "DQN_models"
BEST_DIR = "DQN_best_model"

os.makedirs(LOG_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(BEST_DIR, exist_ok=True)

def make_env():
    def _thunk():
        env = gym.make("CartPole-v1")
        env = Monitor(env, filename=os.path.join(LOG_DIR, "monitor.csv"))
        return env
    return _thunk

venv = DummyVecEnv([make_env()])

# DQN hyperparams 
model = DQN(
    policy="MlpPolicy",
    env=venv,
    learning_rate=1e-3,
    buffer_size=50_000,
    learning_starts=1_000,
    batch_size=64,
    gamma=0.99,
    train_freq=4,
    target_update_interval=1_000,
    exploration_fraction=0.2,
    exploration_final_eps=0.02,
    verbose=1,
    tensorboard_log=LOG_DIR
)

eval_env = gym.make("CartPole-v1")
eval_env = Monitor(eval_env)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=BEST_DIR,
    log_path=LOG_DIR,
    eval_freq=5_000,
    deterministic=True,
    render=False,
)
checkpoint_callback = CheckpointCallback(
    save_freq=10_000,
    save_path=MODEL_DIR,
    name_prefix="dqn_cartpole"
)

# Train
total_timesteps = 200_000
model.learn(total_timesteps=total_timesteps, callback=[eval_callback, checkpoint_callback])

# Save final model
model.save(os.path.join(MODEL_DIR, "dqn_cartpole_final"))
print("Training complete. Saved final model and (if better) best model.")
# Out:
# Using cpu device
# Logging to DQN_logs\DQN_2
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 9678     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 76       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 11363    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 128      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 14331    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 225      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 14560    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 295      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 15094    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 362      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 16013    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 471      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 16630    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 539      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 17141    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 611      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.3     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 17323    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 696      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 17618    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 779      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 17964    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 871      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 18381    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 948      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 14055    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1076     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.263    |
# |    n_updates        | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 11198    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1167     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0178   |
# |    n_updates        | 41       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 9125     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1273     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00727  |
# |    n_updates        | 68       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 8331     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1371     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00303  |
# |    n_updates        | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 7516     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1461     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00122  |
# |    n_updates        | 115      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 7034     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1543     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000235 |
# |    n_updates        | 135      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 6632     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1652     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000243 |
# |    n_updates        | 162      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 6367     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1725     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000304 |
# |    n_updates        | 181      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 6203     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1785     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000315 |
# |    n_updates        | 196      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 6006     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1871     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00039  |
# |    n_updates        | 217      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 5769     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1981     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000177 |
# |    n_updates        | 245      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 5633     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2080     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.033    |
# |    n_updates        | 269      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 5518     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2175     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0217   |
# |    n_updates        | 293      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 5411     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2240     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.032    |
# |    n_updates        | 309      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 5330     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2303     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.027    |
# |    n_updates        | 325      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 5219     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2371     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.021    |
# |    n_updates        | 342      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 5122     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2438     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0134   |
# |    n_updates        | 359      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 5055     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2518     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0062   |
# |    n_updates        | 379      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4973     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2581     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0118   |
# |    n_updates        | 395      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4880     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2683     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0106   |
# |    n_updates        | 420      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4816     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2810     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0201   |
# |    n_updates        | 452      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 4763     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2915     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0104   |
# |    n_updates        | 478      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 4706     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3001     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.483    |
# |    n_updates        | 500      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 4634     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3093     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0599   |
# |    n_updates        | 523      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 4597     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3206     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0969   |
# |    n_updates        | 551      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 4562     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3262     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0847   |
# |    n_updates        | 565      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 4541     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3308     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0391   |
# |    n_updates        | 576      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 4514     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3360     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.054    |
# |    n_updates        | 589      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 4488     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3431     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0814   |
# |    n_updates        | 607      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 4462     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3523     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0567   |
# |    n_updates        | 630      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 4441     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3623     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0574   |
# |    n_updates        | 655      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 4425     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3692     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0735   |
# |    n_updates        | 672      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 4376     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3811     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0313   |
# |    n_updates        | 702      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 4330     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3894     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0706   |
# |    n_updates        | 723      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 4292     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3993     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0328   |
# |    n_updates        | 748      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 4243     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4111     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0475   |
# |    n_updates        | 777      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 4179     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4280     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.114    |
# |    n_updates        | 819      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 4138     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4505     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.136    |
# |    n_updates        | 876      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 4109     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4593     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.132    |
# |    n_updates        | 898      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | 24.5     |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 4085     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4757     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0615   |
# |    n_updates        | 939      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.1     |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 4068     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4880     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.111    |
# |    n_updates        | 969      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.1     |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 4060     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4949     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0428   |
# |    n_updates        | 987      |
# ----------------------------------
# Eval num_timesteps=5000, episode_reward=499.40 +/- 1.20
# Episode length: 499.40 +/- 1.20
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 499      |
# |    mean_reward      | 499      |
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    total_timesteps  | 5000     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0388   |
# |    n_updates        | 999      |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.2     |
# |    ep_rew_mean      | 25.2     |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 3193     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5043     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.21     |
# |    n_updates        | 1010     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | 25.9     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 3191     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5176     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0656   |
# |    n_updates        | 1043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.8     |
# |    ep_rew_mean      | 25.8     |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 3186     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5264     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.174    |
# |    n_updates        | 1065     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.7     |
# |    ep_rew_mean      | 25.7     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 3191     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5377     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0832   |
# |    n_updates        | 1094     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | 25.9     |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 3203     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5506     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0359   |
# |    n_updates        | 1126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | 25.9     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 3208     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5593     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.121    |
# |    n_updates        | 1148     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.7     |
# |    ep_rew_mean      | 25.7     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 3215     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5664     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0719   |
# |    n_updates        | 1165     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | 25.9     |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 3223     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5796     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0124   |
# |    n_updates        | 1198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.2     |
# |    ep_rew_mean      | 26.2     |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 3225     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5884     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.106    |
# |    n_updates        | 1220     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.3     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 3233     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6034     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.2      |
# |    n_updates        | 1258     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.9     |
# |    ep_rew_mean      | 27.9     |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 3240     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6150     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.13     |
# |    n_updates        | 1287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.2     |
# |    ep_rew_mean      | 28.2     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 3242     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6255     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.146    |
# |    n_updates        | 1313     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | 29.1     |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 3248     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6428     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.158    |
# |    n_updates        | 1356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.9     |
# |    ep_rew_mean      | 28.9     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 3241     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6514     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.122    |
# |    n_updates        | 1378     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.4     |
# |    ep_rew_mean      | 29.4     |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 3240     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6627     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.155    |
# |    n_updates        | 1406     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.9     |
# |    ep_rew_mean      | 28.9     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 3238     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6704     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00762  |
# |    n_updates        | 1425     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.5     |
# |    ep_rew_mean      | 29.5     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 3235     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6841     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.145    |
# |    n_updates        | 1460     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 29.2     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 3234     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6910     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.126    |
# |    n_updates        | 1477     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 29       |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 3228     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7012     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.349    |
# |    n_updates        | 1502     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | 29.1     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 3232     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7192     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0614   |
# |    n_updates        | 1547     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.2     |
# |    ep_rew_mean      | 28.2     |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 3233     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7321     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.164    |
# |    n_updates        | 1580     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.8     |
# |    ep_rew_mean      | 28.8     |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 3232     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7477     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.114    |
# |    n_updates        | 1619     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.5     |
# |    ep_rew_mean      | 28.5     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 3236     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7608     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0543   |
# |    n_updates        | 1651     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.4     |
# |    ep_rew_mean      | 28.4     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 3238     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7721     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.062    |
# |    n_updates        | 1680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.4     |
# |    ep_rew_mean      | 29.4     |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 3244     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7889     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.173    |
# |    n_updates        | 1722     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.3     |
# |    ep_rew_mean      | 29.3     |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 3247     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7969     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.203    |
# |    n_updates        | 1742     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.9     |
# |    ep_rew_mean      | 28.9     |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 3246     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 8070     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.268    |
# |    n_updates        | 1767     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.5     |
# |    ep_rew_mean      | 29.5     |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 3245     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 8217     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.113    |
# |    n_updates        | 1804     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 29.9     |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 3245     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 8362     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.216    |
# |    n_updates        | 1840     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31       |
# |    ep_rew_mean      | 31       |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 3254     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 8609     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.129    |
# |    n_updates        | 1902     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.2     |
# |    ep_rew_mean      | 31.2     |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 3255     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 8711     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0931   |
# |    n_updates        | 1927     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.2     |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.782    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 3258     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 8884     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00824  |
# |    n_updates        | 1970     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.1     |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.779    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 3257     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9002     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.51     |
# |    n_updates        | 2000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.3     |
# |    ep_rew_mean      | 33.3     |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 3259     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9216     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0648   |
# |    n_updates        | 2053     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.1     |
# |    ep_rew_mean      | 33.1     |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 3261     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9344     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.167    |
# |    n_updates        | 2085     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.2     |
# |    ep_rew_mean      | 34.2     |
# |    exploration_rate | 0.766    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 3260     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9570     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00996  |
# |    n_updates        | 2142     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.1     |
# |    ep_rew_mean      | 34.1     |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 3260     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9662     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.28     |
# |    n_updates        | 2165     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.4     |
# |    ep_rew_mean      | 34.4     |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 3251     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9868     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.137    |
# |    n_updates        | 2216     |
# ----------------------------------
# Eval num_timesteps=10000, episode_reward=153.80 +/- 14.89
# Episode length: 153.80 +/- 14.89
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 154      |
# |    mean_reward      | 154      |
# | rollout/            |          |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    total_timesteps  | 10000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.227    |
# |    n_updates        | 2249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.3     |
# |    ep_rew_mean      | 35.3     |
# |    exploration_rate | 0.754    |
# | time/               |          |
# ...
# |    learning_rate    | 0.001    |
# |    loss             | 0.0252   |
# |    n_updates        | 47533    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.4     |
# |    ep_rew_mean      | 78.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2828     |
# |    fps              | 2524     |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 191513   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0574   |
# |    n_updates        | 47628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.3     |
# |    ep_rew_mean      | 79.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2832     |
# |    fps              | 2522     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 191806   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.09     |
# |    n_updates        | 47701    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.4     |
# |    ep_rew_mean      | 79.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2836     |
# |    fps              | 2522     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 192163   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0703   |
# |    n_updates        | 47790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.1     |
# |    ep_rew_mean      | 79.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2840     |
# |    fps              | 2522     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 192368   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.05     |
# |    n_updates        | 47841    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.3     |
# |    ep_rew_mean      | 78.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2844     |
# |    fps              | 2523     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 192657   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00706  |
# |    n_updates        | 47914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.6     |
# |    ep_rew_mean      | 76.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2848     |
# |    fps              | 2523     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 192871   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0106   |
# |    n_updates        | 47967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.5     |
# |    ep_rew_mean      | 76.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2852     |
# |    fps              | 2523     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 193223   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00519  |
# |    n_updates        | 48055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77       |
# |    ep_rew_mean      | 77       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2856     |
# |    fps              | 2523     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 193603   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.01     |
# |    n_updates        | 48150    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.1     |
# |    ep_rew_mean      | 77.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2860     |
# |    fps              | 2523     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 193889   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.51     |
# |    n_updates        | 48222    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.2     |
# |    ep_rew_mean      | 77.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2864     |
# |    fps              | 2523     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 194261   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0265   |
# |    n_updates        | 48315    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.9     |
# |    ep_rew_mean      | 77.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2868     |
# |    fps              | 2522     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 194628   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00854  |
# |    n_updates        | 48406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.5     |
# |    ep_rew_mean      | 78.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2872     |
# |    fps              | 2522     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 194934   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.55     |
# |    n_updates        | 48483    |
# ----------------------------------
# Eval num_timesteps=195000, episode_reward=97.20 +/- 2.23
# Episode length: 97.20 +/- 2.23
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 97.2     |
# |    mean_reward      | 97.2     |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 195000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.222    |
# |    n_updates        | 48499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.2     |
# |    ep_rew_mean      | 78.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 2520     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 195226   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.42     |
# |    n_updates        | 48556    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.1     |
# |    ep_rew_mean      | 79.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 2520     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 195601   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0117   |
# |    n_updates        | 48650    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80       |
# |    ep_rew_mean      | 80       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 2520     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 195980   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00503  |
# |    n_updates        | 48744    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.8     |
# |    ep_rew_mean      | 79.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 2520     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 196202   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.809    |
# |    n_updates        | 48800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79       |
# |    ep_rew_mean      | 79       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 2520     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 196492   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00234  |
# |    n_updates        | 48872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78       |
# |    ep_rew_mean      | 78       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 2520     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 196734   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00927  |
# |    n_updates        | 48933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.1     |
# |    ep_rew_mean      | 76.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 2520     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 196898   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.38     |
# |    n_updates        | 48974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.1     |
# |    ep_rew_mean      | 76.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 2520     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 197272   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.801    |
# |    n_updates        | 49067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.3     |
# |    ep_rew_mean      | 75.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 2520     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 197563   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.36     |
# |    n_updates        | 49140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.2     |
# |    ep_rew_mean      | 77.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 2519     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 197956   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0503   |
# |    n_updates        | 49238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.6     |
# |    ep_rew_mean      | 76.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 2519     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 198165   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0992   |
# |    n_updates        | 49291    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.5     |
# |    ep_rew_mean      | 77.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 2520     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 198545   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0252   |
# |    n_updates        | 49386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77       |
# |    ep_rew_mean      | 77       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 2520     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 198840   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.835    |
# |    n_updates        | 49459    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.4     |
# |    ep_rew_mean      | 75.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2928     |
# |    fps              | 2520     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 199053   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.758    |
# |    n_updates        | 49513    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.4     |
# |    ep_rew_mean      | 76.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2932     |
# |    fps              | 2520     |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 199450   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00806  |
# |    n_updates        | 49612    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.3     |
# |    ep_rew_mean      | 77.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2936     |
# |    fps              | 2520     |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 199891   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.27     |
# |    n_updates        | 49722    |
# ----------------------------------
# Eval num_timesteps=200000, episode_reward=127.40 +/- 5.89
# Episode length: 127.40 +/- 5.89
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 127      |
# |    mean_reward      | 127      |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 200000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.13     |
# |    n_updates        | 49749    |
# ----------------------------------
# Training complete. Saved final model and (if better) best model.

# %%
import time

MODEL_PATHS = [
    os.path.join("DQN_best_model", "best_model.zip"),
    os.path.join("DQN_models", "dqn_cartpole_final.zip"),
]

def load_first_available(paths):
    for p in paths:
        if os.path.exists(p):
            return p
    raise FileNotFoundError("No trained model found. Train your model first.")

model_path = load_first_available(MODEL_PATHS)
print(f"Loading model: {model_path}")
model = DQN.load(model_path)

env = gym.make("CartPole-v1", render_mode="human")
obs, info = env.reset(seed=178)

n_episodes = 3
returns = []

for ep in range(n_episodes):
    done = False
    total_reward = 0.0
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(int(action))
        total_reward += reward
        done = terminated or truncated
        # slow down a touch for visibility (optional)
        time.sleep(0.01)
    returns.append(total_reward)
    print(f"Episode {ep+1}: return={total_reward:.1f}")
    obs, info = env.reset()

env.close()
print(f"Average return over {n_episodes} episodes: {np.mean(returns):.1f} ± {np.std(returns):.1f}")
# Out:
# Loading model: DQN_best_model\best_model.zip
# Episode 1: return=500.0
# Episode 2: return=500.0
# Episode 3: return=500.0
# Average return over 3 episodes: 500.0 ± 0.0

# %%
import imageio

def record_cartpole_video(model, video_path="videos/cartpole_run.mp4", episode_length=500):
    os.makedirs(os.path.dirname(video_path), exist_ok=True)
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    obs, info = env.reset(seed=42)
    frames = []
    done = False
    for _ in range(episode_length):
        frame = env.render()
        frames.append(frame)
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(int(action))
        done = terminated or truncated
        if done:
            break
    env.close()
    imageio.mimsave(video_path, frames, fps=30)
    print(f"Video saved to {video_path}")

record_cartpole_video(model, video_path="videos/cartpole_run.mp4")
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Video saved to videos/cartpole_run.mp4
